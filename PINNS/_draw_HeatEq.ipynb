# %%
from HeatEq import *
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D

net = PDENN(input_size=2, output_size=1, hidden_depth=10, hidden_size=12, lr=1.0)
best_model = HeatEq(net, [0, 1], [0, 1], 1000, 1000, False)

# %matplotlib inline
best_model.drawReal(500, 'coolwarm')
# Out:
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.16/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
best_model.net.optim = best_model.net.adam

# %%
best_model.loadBest()
best_model.drawPred(500, 'coolwarm')

# %%
best_model.loadBest()
best_model.drawError(500, 'coolwarm')

# %%
best_model.loadBest()
best_model.drawLossHistory()

# %%
best_model.loadBest()
best_model.drawLossLast(50)

# %%
best_model.loadBest()
best_model.drawLossLast(10)
