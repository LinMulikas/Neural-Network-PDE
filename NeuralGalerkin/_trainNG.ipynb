# %%
import sys
from os import path
sys.path.append(path.dirname(path.dirname(path.abspath('__file__'))))
from NeuralGalerkin import *
from HeatNG import *
from Drawer import Drawer

heat = HeatNG((0, 1), (0, 1), 5000)

best = 'models/best.pt'
nil = ''

net = Net(pde_size = (2, 1), 
          shape = (6, 16), 
          data = heat.data_generator(),
          loadFile = best, lr = 1e-4)

heat.setNet(net)
NG = NeuralGalerkin(heat)
# NG.trainInit(10000)
# Out:
# /home/wangdl/anaconda3/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
NG.pde.net.paramVector()
# Out:
# torch.Size([1697, 1])

# %%
# %matplotlib inline
NG.draw(t = 0)

# %%
t = 0.05
NG.thetaStep(t, 5, 1000)
NG.draw(t)
# Out:
# t step at 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 t = 0.05
# ----> 2 NG.thetaStep(t, 5, 1000)
#       3 NG.draw(t)
#
# File ~/Neural-Network-PDE/NeuralGalerkin.py:26, in NeuralGalerkin.thetaStep(self, t, N_t, N_x, alpha)
#      24 t_current = self.pde.t[0]
#      25 while(t_current <= t):
# ---> 26     M, F = self.calMF(t_current, N_x)
#      27     I = tc.eye(M.shape[0])
#      29     theta_dot = tc.linalg.solve(M + alpha * I, F)
#
# File ~/Neural-Network-PDE/NeuralGalerkin.py:74, in NeuralGalerkin.calMF(self, t, N_x)
#      72 U.requires_grad_()
#      73 U_x = grad(U, data_sample, tc.ones_like(U), True, True)[0][:, 1]
# ---> 74 U_xx = grad(U_x, data_sample, tc.ones_like(U_x), True, True)[0][:, 1]
#      76 F += (U_xx * U_theta)/N_x
#      77 M += tc.mul(U_theta, U_theta.T)/N_x
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/autograd/__init__.py:269, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     267 overridable_args = t_outputs + t_inputs
#     268 if has_torch_function(overridable_args):
# --> 269     return handle_torch_function(
#     270         grad,
#     271         overridable_args,
#     272         t_outputs,
#     273         t_inputs,
#     274         grad_outputs=grad_outputs,
#     275         retain_graph=retain_graph,
#     276         create_graph=create_graph,
#     277         only_inputs=only_inputs,
#     278         allow_unused=allow_unused,
#     279         is_grads_batched=is_grads_batched,
#     280     )
#     282 if not only_inputs:
#     283     warnings.warn("only_inputs argument is deprecated and is ignored now "
#     284                   "(defaults to True). To accumulate gradient for other "
#     285                   "parts of the graph, please use torch.autograd.backward.")
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/overrides.py:1534, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1530 if _is_torch_function_mode_enabled():
#    1531     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1532     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1533     with _pop_mode_temporarily() as mode:
# -> 1534         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1535     if result is not NotImplemented:
#    1536         return result
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/_device.py:62, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      60 if func in _device_constructors() and kwargs.get('device') is None:
#      61     kwargs['device'] = self.device
# ---> 62 return func(*args, **kwargs)
#
# KeyboardInterrupt:
