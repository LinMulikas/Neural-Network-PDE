# %%
import sys
from os import path
sys.path.append(path.dirname(path.dirname(path.abspath('__file__'))))


from NeuralGalerkin import *
from HeatNG import *
from Drawer import Drawer

heat = HeatNG((0, 1), (0, 1), 5000)

best = 'models/best.pt'
nil = ''

net = Net(pde_size = (2, 1), 
          shape = (6, 16), 
          data = heat.data_generator(),
          loadFile = best, lr = 1e-4)

heat.setNet(net)
NG = NeuralGalerkin(heat)
# NG.trainInit(10000)
# Out:
# /home/wangdl/anaconda3/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %%
# %matplotlib inline
NG.draw(t = 0)

# %%
# paraV = NG.pde.net.paramVector()
# NG.pde.net.updateParams(paraV)
# _paraV = NG.pde.net.paramVector()
# paraV[: 32], _paraV[: 32]

# %%
t = 0.05
NG.thetaStep(t, N_t = 10, N_x = 500, alpha = 1e-4)
NG.draw(t)
# Out:
# Step 1, t finished at 0.005
# Step 2, t finished at 0.01
# Step 3, t finished at 0.015
# Step 4, t finished at 0.02
# Step 5, t finished at 0.025
# Step 6, t finished at 0.030000000000000002
# Step 7, t finished at 0.035
